# %% [markdown]
# # The Risk Your AI Assurance Cannot See
#
# ### An eight-minute demonstration
#
# ---
#
# Most organisations have now put an AI assistant on top of their internal documents. Most have
# reviewed it the same way they review any system: check that each document carries the right
# classification, confirm each user has the right access, sign it off.
#
# **We are going to show you a disclosure that survives all of that** — and that appears in no log,
# triggers no alert, and has no misconfiguration to fix.

# %% [markdown]
# ---
# ## First — does this apply to you?

# %%
from bd_helpers import BDDemo

demo = BDDemo(replay=True)      # replay=False calls the model live
demo.does_this_apply()
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ---
# ## Now — you choose
#
# We ran this against four confidential facts. **Which one would hurt most in your organisation?**

# %%
demo.pick_disclosure()
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ---
# ## Watch it happen
#
# *Change the number below to whichever they picked, then run.*

# %%
demo.reveal(3)      # 1 termination · 2 ethics investigation · 3 medical leave · 4 acquisition
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ### That sentence did not exist ten seconds ago.
#
# Not in any document. Not in the store. Not anywhere in the organisation.
#
# The assistant **created** it by joining two records it was fully entitled to read. Neither source
# document is confidential. Neither would be flagged by any classification exercise you have run.

# %% [markdown]
# ---
# ## What it costs

# %%
demo.what_it_costs()
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ---
# ## Why this holds up when your security team reviews it

# %%
demo.credibility()
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ---
# ## What we would do about it

# %%
demo.engagement()
# Out:
# <style>
# .dm      { font-family: -apple-system, 'Segoe UI', sans-serif; max-width: 900px; }
# .dm-q    { background:#F5F7FA; border-left:5px solid #607D8B; padding:14px 18px;
#            border-radius:4px; font-size:17px; color:#263238; margin:6px 0 4px; }
# .dm-lbl  { font-size:11px; letter-spacing:1.4px; text-transform:uppercase;
#            color:#78909C; margin-bottom:6px; font-weight:700; }
# .dm-a    { padding:16px 18px; border-radius:4px; font-size:19px; line-height:1.55;
#            margin:4px 0 10px; }
# .dm-ok   { background:#E8F5E9; border-left:5px solid #2E7D32; color:#1B5E20; }
# .dm-bad  { background:#FFEBEE; border-left:5px solid #C62828; color:#B71C1C;
#            font-weight:600; font-size:22px; }
# .dm-tag  { display:inline-block; padding:5px 14px; border-radius:3px;
#            font-size:13px; font-weight:700; letter-spacing:.5px; margin-top:4px; }
# .dm-tok  { background:#2E7D32; color:#fff; }
# .dm-tbad { background:#C62828; color:#fff; }
# ...

# %% [markdown]
# ---
#
# # The one-sentence version
#
# > **Your access controls are working. That is the problem —**
# > **they are answering a question about documents, and the risk is in the answers.**
#
# ---
#
# ### The natural next step
#
# A **two-week diagnostic** on one assistant you already run. We map what it can reach, build a probe
# set against your own corpus and roles, and tell you whether this failure exists in your environment.
#
# It is scoped to be small enough to say yes to, and specific enough to be worth doing.
#
# ---
#
# *Reference scenario built on a public corpus. It demonstrates one failure class; it is not a claim
# about any particular system.*
